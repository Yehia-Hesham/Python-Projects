# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df_client = pd.read_csv("../Datasets/client_data.csv",index_col='id')

# %%
df_client
# Out:
#                                                      channel_sales  cons_12m  \
# id
# 24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua         0
# d29c2c54acc38ff3c0614d0a653813dd                           MISSING      4660
# 764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua       544
# bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema      1584
# 149d57cf92fc41cf94415803a877cb4b                           MISSING      4425
# ...                                                            ...       ...
# 18463073fb097fc0ac5d3e040f356987  foosdfpfkusacimwkcsosbicdxkicaua     32270
# d0a6f71671571ed83b2645d23af6de00  foosdfpfkusacimwkcsosbicdxkicaua      7223
# 10e6828ddd62cbcf687cb74928c4c2d2  foosdfpfkusacimwkcsosbicdxkicaua      1844
# 1cf20fd6206d7678d5bcafd28c53b4db  foosdfpfkusacimwkcsosbicdxkicaua       131
# 563dde550fd624d7352f3de77c0cdfcd                           MISSING      8730
#
# ...

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df_client.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14606 entries, 24011ae4ebbe3035111d65fa7c15bc57 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   channel_sales                   10881 non-null  object
#  1   cons_12m                        14606 non-null  int64
#  2   cons_gas_12m                    14606 non-null  int64
#  3   cons_last_month                 14606 non-null  int64
#  4   date_activ                      14606 non-null  datetime64[ns]
#  5   date_end                        14606 non-null  datetime64[ns]
#  6   date_modif_prod                 14606 non-null  datetime64[ns]
#  7   date_renewal                    14606 non-null  datetime64[ns]
#  8   forecast_cons_12m               14606 non-null  float64
#  9   forecast_cons_year              14606 non-null  int64
# ...

# %% [markdown]
# <font color = 'blue'><h2>Note: Column 'activity_new' is missing from the data</h2></font>

# %%
df_client['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    6754
# MISSING                             3725
# lmkebamcaaclubfxadlmueccxoimlema    1843
# usilxuppasemubllopkaafesmlibmsdf    1375
# ewpakwlliwisiwduibdlfmalxowmwpci     893
# sddiedcslfslkckwlfkdpoeeailfpeds      11
# epumfxlbckeskwekxbiuasklxalciiuu       3
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: channel_sales, dtype: int64

# %%
df_client['channel_sales'] = df_client['channel_sales'].apply(lambda x: np.nan if x == 'MISSING' else x)

# %%
df_client['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    6754
# lmkebamcaaclubfxadlmueccxoimlema    1843
# usilxuppasemubllopkaafesmlibmsdf    1375
# ewpakwlliwisiwduibdlfmalxowmwpci     893
# sddiedcslfslkckwlfkdpoeeailfpeds      11
# epumfxlbckeskwekxbiuasklxalciiuu       3
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: channel_sales, dtype: int64

# %%
data = df_client.churn.value_counts().sort_index()
data
# Out:
# 0    13187
# 1     1419
# Name: churn, dtype: int64

# %%
sns.countplot(data =df_client, y='pow_max')
# Out:
# <AxesSubplot:xlabel='count', ylabel='pow_max'>

# %%
df_client.keys()
# Out:
# Index(['channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')

# %%
cats_num = ['channel_sales','has_gas','origin_up']

# %%
cats_ord = ['forecast_discount_energy','forecast_price_pow_off_peak','nb_prod_act']

# %%
nums = ['cons_12m','cons_gas_12m','cons_last_month','forecast_cons_12m','forecast_cons_year','forecast_meter_rent_12m',
       'forecast_price_energy_off_peak','forecast_price_energy_peak','imp_cons','margin_gross_pow_ele','net_margin',
        'num_years_antig','pow_max']

# %%
dates = ['date_activ','date_end','date_modif_prod','date_renewal']

# %%
result = ['churn']

# %% [markdown]
# <font color ='blue'>Note: we decided to put 'num_years_antig' as a numerical variable instead of categorical to prevent newer values larger than 13 from destroying the model.<br>
# same with 'pow_max', to prevent adding new subsrciption packages from breaking the system.</font>

# %%
for date in dates:
    df_client[date] = pd.to_datetime(df_client[date])

# %%
df_client[dates].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14606 entries, 24011ae4ebbe3035111d65fa7c15bc57 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date_activ       14606 non-null  datetime64[ns]
#  1   date_end         14606 non-null  datetime64[ns]
#  2   date_modif_prod  14606 non-null  datetime64[ns]
#  3   date_renewal     14606 non-null  datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 1.1+ MB

# %%
sns.pairplot(data = df_client[cats_ord],height=2.5);

# %%
sns.pairplot(data = df_client[nums],height=2.5);

# %%
df_client[nums].corr()
# Out:
#                                 cons_12m  cons_gas_12m  cons_last_month  \
# cons_12m                        1.000000      0.488474         0.968212
# cons_gas_12m                    0.488474      1.000000         0.507007
# cons_last_month                 0.968212      0.507007         1.000000
# forecast_cons_12m               0.193947      0.084359         0.177773
# forecast_cons_year              0.167093      0.080934         0.193574
# forecast_meter_rent_12m         0.065268      0.041393         0.057476
# forecast_price_energy_off_peak -0.007748     -0.017684        -0.005187
# forecast_price_energy_peak      0.145908      0.074002         0.136802
# imp_cons                        0.159711      0.077846         0.187034
# margin_gross_pow_ele           -0.011926      0.006868        -0.011498
# net_margin                      0.133614      0.070867         0.121835
# num_years_antig                -0.003565     -0.013815        -0.003677
# ...
